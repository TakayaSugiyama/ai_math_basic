# %%
import numpy as np 
import matplotlib.pyplot as plt 

a = 1.5   #定数
x = np.linspace(-1,3)
y = a * x

plt.plot(x,y)
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 

b = 3
x =np.linspace(-1,1)
y = b * x
plt.plot(x,y)
plt.show()
